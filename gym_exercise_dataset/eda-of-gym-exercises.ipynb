# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/gym-exercise-data/megaGymDataset.csv

# %%
# Import libraries and read the csv file into a dataframe
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/kaggle/input/gym-exercise-data/megaGymDataset.csv', index_col=0)
df.sample(10)
# Out:
#                                                Title  \
# 1078                     Single-arm cable cross-over
# 2895                                         TBS Dip
# 610                           Cross-body plank march
# 2596                                  AM Front Raise
# 484                 Holman Shoulder Tap to Dirty Dog
# 2259                      HM Reverse Lunge with Kick
# 2914  Lying Close-Grip Barbell Triceps Press To Chin
# 2456                             Barbell upright row
# 67        Holman Straight Plank Dumbbell Reach-Under
# 2223                   HM Alternating Lunge-In-Place
#
#                                                    Desc      Type    BodyPart  \
# 1078  The single-arm cable cross-over is an isolatio...  Strength       Chest
# 2895  The triceps dip is a machine version of an exe...  Strength     Triceps
# 610   The cross-body plank march is an exercise targ...  Strength  Abdominals
# 2596  The alternating dumbbell front raise is an iso...  Strength   Shoulders
# 484                                                 NaN  Strength  Abdominals
# 2259                                                NaN  Strength  Quadriceps
# 2914                                                NaN  Strength     Triceps
# 2456  The barbell upright row is a barbell exercise ...  Strength   Shoulders
# 67                                                  NaN  Strength  Abdominals
# 2223                                                NaN  Strength  Quadriceps
#
#          Equipment         Level  Rating RatingDesc
# 1078         Cable  Intermediate     8.6    Average
# 2895     Body Only  Intermediate     NaN        NaN
# 610      Body Only  Intermediate     NaN        NaN
# 2596      Dumbbell  Intermediate     NaN        NaN
# 484      Body Only  Intermediate     NaN        NaN
# 2259     Body Only  Intermediate     NaN        NaN
# 2914  E-Z Curl Bar      Beginner     8.1    Average
# 2456       Barbell  Intermediate     8.3    Average
# 67        Dumbbell  Intermediate     NaN        NaN
# 2223     Body Only  Intermediate     NaN        NaN

# %%
# Function that provides quick and useful information about the dataframe
def GiveBasicDetails(data):
    print("Dataframe Size: ",data.shape)
    print("############################")
    print(data.info())
    print("############################")
    print(data.describe())
    print("############################")
    print(data.isna().sum()*100/data.shape[0])

GiveBasicDetails(df)
# Out:
# Dataframe Size:  (2918, 8)
# ############################
# <class 'pandas.core.frame.DataFrame'>
# Index: 2918 entries, 0 to 2917
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       2918 non-null   object
#  1   Desc        1368 non-null   object
#  2   Type        2918 non-null   object
#  3   BodyPart    2918 non-null   object
#  4   Equipment   2886 non-null   object
#  5   Level       2918 non-null   object
#  6   Rating      1031 non-null   float64
#  7   RatingDesc  862 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 205.2+ KB
# None
# ############################
#             Rating
# count  1031.000000
# mean      5.919690
# std       3.584607
# min       0.000000
# 25%       3.000000
# 50%       7.900000
# 75%       8.700000
# max       9.600000
# ############################
# Title          0.000000
# Desc          53.118574
# Type           0.000000
# BodyPart       0.000000
# Equipment      1.096642
# Level          0.000000
# Rating        64.667581
# RatingDesc    70.459219
# dtype: float64

# %%
# Listing the number of data entries for each categorical variable
cat_cols = ['Type','BodyPart','Equipment','Level','RatingDesc']

for i in cat_cols:
    print(df[i].value_counts())
    print('#####################################')
# Out:
# Type
# Strength                 2545
# Stretching                147
# Plyometrics                97
# Powerlifting               37
# Cardio                     35
# Olympic Weightlifting      35
# Strongman                  22
# Name: count, dtype: int64
# #####################################
# BodyPart
# Abdominals     662
# Quadriceps     646
# Shoulders      340
# Chest          262
# Biceps         168
# Triceps        151
# Lats           124
# Hamstrings     121
# Middle Back    118
# Lower Back      97
# Glutes          81
# Calves          47
# Forearms        31
# Traps           24
# Abductors       21
# Adductors       17
# Neck             8
# Name: count, dtype: int64
# #####################################
# Equipment
# Body Only        1078
# Dumbbell          516
# Barbell           282
# Other             254
# Cable             226
# Machine           175
# Kettlebells       149
# Bands             100
# Medicine Ball      38
# Exercise Ball      35
# E-Z Curl Bar       22
# Foam Roll          11
# Name: count, dtype: int64
# #####################################
# Level
# Intermediate    2446
# Beginner         459
# Expert            13
# Name: count, dtype: int64
# #####################################
# RatingDesc
# Average    862
# Name: count, dtype: int64
# #####################################

# %%
# Drop any rows that have a null value for Rating
df_rated = df.dropna(subset=['Rating'])
df_rated.isna().sum()
# Out:
# Title           0
# Desc          436
# Type            0
# BodyPart        0
# Equipment      29
# Level           0
# Rating          0
# RatingDesc    169
# dtype: int64

# %%
df_rated.drop(columns=['RatingDesc'], inplace=True)
# Out:
# /tmp/ipykernel_20/3786254758.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rated.drop(columns=['RatingDesc'], inplace=True)

# %%
# Check the value counts for Rating
df_rated['Rating'].value_counts()
# Out:
# Rating
# 0.0    244
# 8.8     52
# 8.3     49
# 9.0     43
# 8.7     42
#       ...
# 2.4      2
# 3.5      1
# 2.5      1
# 1.6      1
# 6.1      1
# Name: count, Length: 72, dtype: int64

# %%
# Only include rows where the Rating is nonzero
df_rated = df_rated[df_rated['Rating']!=0.0]

# %%
# Distribution of ratings
sns.histplot(df_rated)
# Out:
# <Axes: ylabel='Count'>

# %%
# Finding the mean Ratings and boxplots based on exercise type, bodypart used, equipment used, and level of difficulty
for i in cat_cols[0:4]:
    print(df_rated.groupby(i).Rating.mean().sort_values(ascending=False))
    plt.figure(figsize=(20,10))
    sns.boxplot(x=i, y='Rating', data=df_rated)
    plt.show()
    print()
# Out:
# Type
# Cardio                   8.512500
# Olympic Weightlifting    8.433333
# Powerlifting             8.365385
# Strength                 8.277256
# Strongman                7.984615
# Plyometrics              7.571795
# Stretching               4.890435
# Name: Rating, dtype: float64
# BodyPart
# Biceps         8.254902
# Triceps        8.187273
# Abdominals     8.187209
# Forearms       8.109091
# Traps          8.018750
# Chest          7.990698
# Shoulders      7.928182
# Middle Back    7.862162
# Quadriceps     7.820312
# Hamstrings     7.537931
# Lats           7.258974
# Lower Back     6.816000
# Glutes         6.795455
# Neck           6.550000
# Abductors      6.487500
# Adductors      6.270000
# Calves         6.257692
# Name: Rating, dtype: float64
# Equipment
# E-Z Curl Bar     8.600000
# Dumbbell         8.446400
# Barbell          8.396377
# Cable            8.346753
# Machine          8.301538
# Kettlebells      7.689189
# Other            7.589873
# Exercise Ball    7.150000
# Body Only        7.039011
# Medicine Ball    6.912500
# Bands            6.842105
# Foam Roll        5.344444
# Name: Rating, dtype: float64
# Level
# Expert          8.371429
# Intermediate    7.975378
# Beginner        7.419558
# Name: Rating, dtype: float64

# %%
# Showing the highest and lowest rated exercises in all categories
for i in cat_cols[0:4]:
    df_sorted = df_rated.sort_values(by=[i, 'Rating'], ascending=[True, False])
    print(df_sorted.groupby(i).first())
    print(df_sorted.groupby(i).last())
# Out:
#                                       Title  \
# Type
# Cardio                         Jumping rope
# Olympic Weightlifting     Clean from Blocks
# Plyometrics             Single Leg Push-off
# Powerlifting           Barbell glute bridge
# Strength                   Single-Leg Press
# Stretching             Standing Hip Circles
# Strongman                    Rickshaw Carry
#
#                                                                     Desc  \
# Type
# Cardio                 Jumping rope is a classic conditioning exercis...
# Olympic Weightlifting  The push-press is an overhead press variation ...
# Plyometrics            The side-to-side box skip is an explosive lowe...
# Powerlifting           The barbell glute bridge is a popular exercise...
# Strength               The single-leg leg press is an exercise target...
# Stretching             The standing leg swing is a dynamic stretching...
# Strongman              The dumbbell farmer's walk is an exercise with...
#
#                          BodyPart  Equipment         Level  Rating
# Type
# Cardio                 Quadriceps  Body Only  Intermediate     9.2
# Olympic Weightlifting  Quadriceps    Barbell      Beginner     9.5
# Plyometrics            Quadriceps      Other      Beginner     9.2
# Powerlifting               Glutes    Barbell  Intermediate     9.4
# Strength               Quadriceps    Machine  Intermediate     9.6
# Stretching              Abductors  Body Only      Beginner     8.8
# Strongman                Forearms      Other      Beginner     9.6
#                                             Title  \
# Type
# Cardio                                 Sled push-
# Olympic Weightlifting                Snatch Shrug
# Plyometrics             Medicine ball scoop throw
# Powerlifting                          Chain Press
# Strength               Double-kettlebell windmill
# Stretching                                Pyramid
# Strongman                                Crucifix
#
#                                                                     Desc  \
# Type
# Cardio                 The sled push is a conditioning exercise that ...
# Olympic Weightlifting  The behind-the-head push-press is an overhead ...
# Plyometrics            The medicine ball scoop throw is an explosive ...
# Powerlifting           The board bench press is an upper-body exercis...
# Strength               The double-kettlebell windmill is an advanced ...
# Stretching             The single-leg lying cross-over stretch is a s...
# Strongman              The sled push is a conditioning exercise that ...
#
#                          BodyPart      Equipment         Level  Rating
# Type
# Cardio                 Hamstrings          Other      Beginner     7.4
# Olympic Weightlifting       Traps        Barbell      Beginner     6.2
# Plyometrics             Shoulders  Medicine Ball  Intermediate     3.4
# Powerlifting                Chest          Other      Beginner     5.6
# Strength                Shoulders    Kettlebells  Intermediate     3.0
# Stretching             Lower Back      Body Only  Intermediate     1.0
# Strongman               Shoulders          Other      Beginner     6.0
#                                              Title  \
# BodyPart
# Abdominals                          Landmine twist
# Abductors                     Standing Hip Circles
# Adductors                           Thigh adductor
# Biceps                        Incline Hammer Curls
# Calves                    Smith Machine Calf Raise
# Chest                                      Pushups
# Forearms                            Rickshaw Carry
# Glutes                        Barbell glute bridge
# Hamstrings                        Barbell Deadlift
# Lats                              Weighted pull-up
# Lower Back                            Atlas Stones
# Middle Back                  T-Bar Row with Handle
# Neck         Lying Face Down Plate Neck Resistance
# Quadriceps                        Single-Leg Press
# Shoulders    Dumbbell front raise to lateral raise
# Traps                          Smith machine shrug
# Triceps                                Triceps dip
#
#                                                           Desc          Type  \
# BodyPart
# Abdominals   The landmine twist is a rotational abdominal m...      Strength
# Abductors    Iliotibial band self-myofascial release (SMR) ...    Stretching
# Adductors    The thigh adductor machine is a lower-body exe...      Strength
# Biceps       The wide-grip barbell curl is a variation of t...      Strength
# Calves       The Smith machine standing calf raise is a mac...      Strength
# Chest        The push-up is a popular bodyweight exercise t...      Strength
# Forearms     The palms-down wrist curl over bench is an exe...     Strongman
# Glutes       The barbell glute bridge is a popular exercise...  Powerlifting
# Hamstrings   The barbell deadlift is a compound exercise us...      Strength
# Lats         The weighted pull-up is a more advanced variat...      Strength
# Lower Back   The barbell deficit deadlift is a compound exe...     Strongman
# Middle Back  The reverse-grip bent-over row is a compound e...      Strength
# Neck                                                      None      Strength
# Quadriceps   The single-leg leg press is an exercise target...      Strength
# Shoulders    The dumbbell front raise to lateral raise is a...      Strength
# Traps        The Smith machine shrug is an upper-body exerc...      Strength
# Triceps      The triceps dip is a bodyweight exercise perfo...      Strength
#
#              Equipment         Level  Rating
# BodyPart
# Abdominals       Other  Intermediate     9.5
# Abductors    Body Only      Beginner     8.8
# Adductors      Machine  Intermediate     9.0
# Biceps        Dumbbell      Beginner     9.5
# Calves         Machine  Intermediate     9.2
# Chest        Body Only  Intermediate     9.2
# Forearms         Other      Beginner     9.6
# Glutes         Barbell  Intermediate     9.4
# Hamstrings     Barbell  Intermediate     9.4
# Lats             Other  Intermediate     9.5
# Lower Back       Other  Intermediate     9.5
# Middle Back      Other  Intermediate     9.5
# Neck             Other      Beginner     9.3
# Quadriceps     Machine  Intermediate     9.6
# Shoulders     Dumbbell  Intermediate     9.5
# Traps          Machine  Intermediate     9.2
# Triceps      Body Only  Intermediate     9.4
#                                            Title  \
# BodyPart
# Abdominals                      Overhead Stretch
# Abductors    Single-leg lying cross-over stretch
# Adductors                   Lying Bent Leg Groin
# Biceps                            Brachialis SMR
# Calves                Posterior Tibialis Stretch
# Chest             Pass-through stretch with band
# Forearms                           Wrist Circles
# Glutes                         One Knee To Chest
# Hamstrings            Chair Leg Extended Stretch
# Lats                    Side-Lying Floor Stretch
# Lower Back                               Pyramid
# Middle Back                  Middle Back Stretch
# Neck                                    Neck-SMR
# Quadriceps        Standing Elevated Quad Stretch
# Shoulders             Double-kettlebell windmill
# Traps                               Snatch Shrug
# Triceps                         Overhead Triceps
#
#                                                           Desc  \
# BodyPart
# Abdominals   The seated bar twist is a core exercise meant ...
# Abductors    The single-leg lying cross-over stretch is a s...
# Adductors    Adductor self-myofascial release (SMR) is a se...
# Biceps       Brachialis self-myofascial release (SMR) is a ...
# Calves       The wall calf stretch is a stretch targeting t...
# Chest        The pass-through stretch with band is a popula...
# Forearms     The partner farmer's walk is a protocol for pe...
# Glutes       The lying glute stretch is a stretch to help i...
# Hamstrings   The alternating lunge jump is an explosive bod...
# Lats         The standing side bend stretch is a stretching...
# Lower Back   Lower back self-myofascial release (SMR) is a ...
# Middle Back  Rhomboids self-myofascial release (SMR) is a s...
# Neck                                                      None
# Quadriceps   The lying quad stretch with band is a simple w...
# Shoulders    The double-kettlebell windmill is an advanced ...
# Traps        The Smith machine upright row is an upper-body...
# Triceps      The incline cable straight-bar triceps extensi...
#
#                               Type    Equipment         Level  Rating
# BodyPart
# Abdominals              Stretching    Body Only  Intermediate     3.9
# Abductors               Stretching    Body Only      Beginner     1.6
# Adductors               Stretching        Other      Beginner     2.8
# Biceps                  Stretching    Foam Roll      Beginner     3.2
# Calves                  Stretching        Bands  Intermediate     1.0
# Chest                   Stretching        Other      Beginner     3.0
# Forearms                Stretching    Body Only      Beginner     2.5
# Glutes                  Stretching    Body Only  Intermediate     2.7
# Hamstrings              Stretching        Other      Beginner     2.4
# Lats                    Stretching        Other      Beginner     1.0
# Lower Back              Stretching    Body Only  Intermediate     1.0
# Middle Back             Stretching    Body Only  Intermediate     3.8
# Neck                    Stretching    Body Only  Intermediate     2.8
# Quadriceps              Stretching    Body Only  Intermediate     2.7
# Shoulders                 Strength  Kettlebells  Intermediate     3.0
# Traps        Olympic Weightlifting      Barbell      Beginner     6.2
# Triceps                 Stretching    Body Only      Beginner     3.3
#                                           Title  \
# Equipment
# Bands                    Single-leg depth squat
# Barbell        Palms-down wrist curl over bench
# Body Only                           Triceps dip
# Cable          Standing cable low-to-high twist
# Dumbbell                   Incline Hammer Curls
# E-Z Curl Bar        Decline EZ-bar skullcrusher
# Exercise Ball             Exercise Ball Pull-In
# Foam Roll                   Iliotibial band SMR
# Kettlebells    Single-arm kettlebell push-press
# Machine                        Single-Leg Press
# Medicine Ball          Dumbbell suitcase crunch
# Other                            Rickshaw Carry
#
#                                                             Desc        Type  \
# Equipment
# Bands          The single-leg depth squat is an exercise targ...    Strength
# Barbell        The palms-down wrist curl over bench is an exe...    Strength
# Body Only      The triceps dip is a bodyweight exercise perfo...    Strength
# Cable          The standing cable low-to-high twist is a core...    Strength
# Dumbbell       The dumbbell front raise to lateral raise is a...    Strength
# E-Z Curl Bar   The decline EZ-bar skullcrusher is a popular e...    Strength
# Exercise Ball  The exercise ball knee roll-in is an abdominal...    Strength
# Foam Roll      Iliotibial band self-myofascial release (SMR) ...  Stretching
# Kettlebells    The single-arm kettlebell push-press is a popu...    Strength
# Machine        The single-leg leg press is an exercise target...    Strength
# Medicine Ball  The dumbbell suitcase crunch is a weighted ver...    Strength
# Other          The landmine twist is a rotational abdominal m...   Strongman
#
#                  BodyPart         Level  Rating
# Equipment
# Bands          Quadriceps  Intermediate     9.0
# Barbell          Forearms  Intermediate     9.5
# Body Only         Triceps  Intermediate     9.4
# Cable          Abdominals  Intermediate     9.3
# Dumbbell           Biceps      Beginner     9.5
# E-Z Curl Bar      Triceps  Intermediate     9.3
# Exercise Ball  Abdominals  Intermediate     8.9
# Foam Roll       Abductors  Intermediate     8.2
# Kettlebells     Shoulders  Intermediate     9.3
# Machine        Quadriceps  Intermediate     9.6
# Medicine Ball  Abdominals  Intermediate     9.0
# Other            Forearms      Beginner     9.6
#                                           Title  \
# Equipment
# Bands                Posterior Tibialis Stretch
# Barbell                        Seated bar twist
# Body Only                               Pyramid
# Cable                           Cable Judo Flip
# Dumbbell               Calf Raise On A Dumbbell
# E-Z Curl Bar   Close-Grip EZ-Bar Curl with Band
# Exercise Ball       Exercise ball chest stretch
# Foam Roll                        Brachialis SMR
# Kettlebells          Double-kettlebell windmill
# Machine              Smith machine pistol squat
# Medicine Ball         Medicine ball scoop throw
# Other                              Overhead Lat
#
#                                                             Desc         Type  \
# Equipment
# Bands          The band-assisted pull-up is a variation of th...   Stretching
# Barbell        The seated bar twist is a core exercise meant ...     Strength
# Body Only      The single-leg lying cross-over stretch is a s...   Stretching
# Cable          The incline cable straight-bar triceps extensi...     Strength
# Dumbbell       The partner farmer's walk is a protocol for pe...     Strength
# E-Z Curl Bar   The EZ-bar skullcrusher is a popular exercise ...     Strength
# Exercise Ball  The exercise ball chest stretch is a simple st...   Stretching
# Foam Roll      Brachialis self-myofascial release (SMR) is a ...   Stretching
# Kettlebells    The double-kettlebell windmill is an advanced ...     Strength
# Machine        The Smith machine pistol squat is a machine-ba...     Strength
# Medicine Ball  The medicine ball scoop throw is an explosive ...  Plyometrics
# Other          The pass-through stretch with band is a popula...   Stretching
#
#                  BodyPart         Level  Rating
# Equipment
# Bands              Calves  Intermediate     1.0
# Barbell        Abdominals  Intermediate     4.7
# Body Only      Lower Back  Intermediate     1.0
# Cable          Abdominals      Beginner     5.0
# Dumbbell           Calves      Beginner     4.8
# E-Z Curl Bar       Biceps      Beginner     7.9
# Exercise Ball       Chest      Beginner     3.6
# Foam Roll          Biceps      Beginner     3.2
# Kettlebells     Shoulders  Intermediate     3.0
# Machine        Quadriceps  Intermediate     7.0
# Medicine Ball   Shoulders  Intermediate     3.4
# Other                Lats      Beginner     1.0
#                          Title  \
# Level
# Beginner        Rickshaw Carry
# Expert           Power snatch-
# Intermediate  Single-Leg Press
#
#                                                            Desc  \
# Level
# Beginner      The dumbbell stiff-legged deadlift targets the...
# Expert        The power snatch is a full-body lift in which ...
# Intermediate  The single-leg leg press is an exercise target...
#
#                                Type    BodyPart Equipment  Rating
# Level
# Beginner                  Strongman    Forearms     Other     9.6
# Expert        Olympic Weightlifting  Quadriceps   Barbell     9.3
# Intermediate               Strength  Quadriceps   Machine     9.6
#                                              Title  \
# Level
# Beginner                  Side-Lying Floor Stretch
# Expert        Single-arm kettlebell overhead squat
# Intermediate                               Pyramid
#
#                                                            Desc        Type  \
# Level
# Beginner      The single-leg lying cross-over stretch is a s...  Stretching
# Expert        The single-arm kettlebell overhead squat is a ...    Strength
# Intermediate  The double-kettlebell windmill is an advanced ...  Stretching
#
#                 BodyPart    Equipment  Rating
# Level
# Beginner            Lats        Other     1.0
# Expert        Quadriceps  Kettlebells     7.0
# Intermediate  Lower Back    Body Only     1.0

# %%
# Same as cell above but with maunally customizable category i for a more visually pleasing output
i = 'BodyPart'
df_sorted = df_rated.sort_values(by=[i, 'Rating'], ascending=[True, False])
df_sorted.groupby(i).first()
# Out:
#                                              Title  \
# BodyPart
# Abdominals                          Landmine twist
# Abductors                     Standing Hip Circles
# Adductors                           Thigh adductor
# Biceps                        Incline Hammer Curls
# Calves                    Smith Machine Calf Raise
# Chest                                      Pushups
# Forearms                            Rickshaw Carry
# Glutes                        Barbell glute bridge
# Hamstrings                        Barbell Deadlift
# Lats                              Weighted pull-up
# Lower Back                            Atlas Stones
# Middle Back                  T-Bar Row with Handle
# Neck         Lying Face Down Plate Neck Resistance
# Quadriceps                        Single-Leg Press
# Shoulders    Dumbbell front raise to lateral raise
# Traps                          Smith machine shrug
# Triceps                                Triceps dip
#
#                                                           Desc          Type  \
# BodyPart
# Abdominals   The landmine twist is a rotational abdominal m...      Strength
# Abductors    Iliotibial band self-myofascial release (SMR) ...    Stretching
# Adductors    The thigh adductor machine is a lower-body exe...      Strength
# Biceps       The wide-grip barbell curl is a variation of t...      Strength
# Calves       The Smith machine standing calf raise is a mac...      Strength
# Chest        The push-up is a popular bodyweight exercise t...      Strength
# Forearms     The palms-down wrist curl over bench is an exe...     Strongman
# Glutes       The barbell glute bridge is a popular exercise...  Powerlifting
# Hamstrings   The barbell deadlift is a compound exercise us...      Strength
# Lats         The weighted pull-up is a more advanced variat...      Strength
# Lower Back   The barbell deficit deadlift is a compound exe...     Strongman
# Middle Back  The reverse-grip bent-over row is a compound e...      Strength
# Neck                                                      None      Strength
# Quadriceps   The single-leg leg press is an exercise target...      Strength
# Shoulders    The dumbbell front raise to lateral raise is a...      Strength
# Traps        The Smith machine shrug is an upper-body exerc...      Strength
# Triceps      The triceps dip is a bodyweight exercise perfo...      Strength
#
#              Equipment         Level  Rating
# BodyPart
# Abdominals       Other  Intermediate     9.5
# Abductors    Body Only      Beginner     8.8
# Adductors      Machine  Intermediate     9.0
# Biceps        Dumbbell      Beginner     9.5
# Calves         Machine  Intermediate     9.2
# Chest        Body Only  Intermediate     9.2
# Forearms         Other      Beginner     9.6
# Glutes         Barbell  Intermediate     9.4
# Hamstrings     Barbell  Intermediate     9.4
# Lats             Other  Intermediate     9.5
# Lower Back       Other  Intermediate     9.5
# Middle Back      Other  Intermediate     9.5
# Neck             Other      Beginner     9.3
# Quadriceps     Machine  Intermediate     9.6
# Shoulders     Dumbbell  Intermediate     9.5
# Traps          Machine  Intermediate     9.2
# Triceps      Body Only  Intermediate     9.4

# %%
df_sorted.groupby(i).last()
# Out:
#                                            Title  \
# BodyPart
# Abdominals                      Overhead Stretch
# Abductors    Single-leg lying cross-over stretch
# Adductors                   Lying Bent Leg Groin
# Biceps                            Brachialis SMR
# Calves                Posterior Tibialis Stretch
# Chest             Pass-through stretch with band
# Forearms                           Wrist Circles
# Glutes                         One Knee To Chest
# Hamstrings            Chair Leg Extended Stretch
# Lats                    Side-Lying Floor Stretch
# Lower Back                               Pyramid
# Middle Back                  Middle Back Stretch
# Neck                                    Neck-SMR
# Quadriceps        Standing Elevated Quad Stretch
# Shoulders             Double-kettlebell windmill
# Traps                               Snatch Shrug
# Triceps                         Overhead Triceps
#
#                                                           Desc  \
# BodyPart
# Abdominals   The seated bar twist is a core exercise meant ...
# Abductors    The single-leg lying cross-over stretch is a s...
# Adductors    Adductor self-myofascial release (SMR) is a se...
# Biceps       Brachialis self-myofascial release (SMR) is a ...
# Calves       The wall calf stretch is a stretch targeting t...
# Chest        The pass-through stretch with band is a popula...
# Forearms     The partner farmer's walk is a protocol for pe...
# Glutes       The lying glute stretch is a stretch to help i...
# Hamstrings   The alternating lunge jump is an explosive bod...
# Lats         The standing side bend stretch is a stretching...
# Lower Back   Lower back self-myofascial release (SMR) is a ...
# Middle Back  Rhomboids self-myofascial release (SMR) is a s...
# Neck                                                      None
# Quadriceps   The lying quad stretch with band is a simple w...
# Shoulders    The double-kettlebell windmill is an advanced ...
# Traps        The Smith machine upright row is an upper-body...
# Triceps      The incline cable straight-bar triceps extensi...
#
#                               Type    Equipment         Level  Rating
# BodyPart
# Abdominals              Stretching    Body Only  Intermediate     3.9
# Abductors               Stretching    Body Only      Beginner     1.6
# Adductors               Stretching        Other      Beginner     2.8
# Biceps                  Stretching    Foam Roll      Beginner     3.2
# Calves                  Stretching        Bands  Intermediate     1.0
# Chest                   Stretching        Other      Beginner     3.0
# Forearms                Stretching    Body Only      Beginner     2.5
# Glutes                  Stretching    Body Only  Intermediate     2.7
# Hamstrings              Stretching        Other      Beginner     2.4
# Lats                    Stretching        Other      Beginner     1.0
# Lower Back              Stretching    Body Only  Intermediate     1.0
# Middle Back             Stretching    Body Only  Intermediate     3.8
# Neck                    Stretching    Body Only  Intermediate     2.8
# Quadriceps              Stretching    Body Only  Intermediate     2.7
# Shoulders                 Strength  Kettlebells  Intermediate     3.0
# Traps        Olympic Weightlifting      Barbell      Beginner     6.2
# Triceps                 Stretching    Body Only      Beginner     3.3
